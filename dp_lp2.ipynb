# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/
# Out:
# /content/drive/Othercomputers/My Mac/transfer_learning

# %%
# %pip install .
# Out:
# Processing /content/drive/Othercomputers/My Mac/transfer_learning
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 9.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.0 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/shuqike/quinine.git
# Out:
# ...
#   Cloning https://github.com/shuqike/quinine.git to /tmp/pip-req-build-x_g5pdc6
#   Running command git clone --filter=blob:none --quiet https://github.com/shuqike/quinine.git /tmp/pip-req-build-x_g5pdc6
#   Resolved https://github.com/shuqike/quinine.git to commit 77b7195f6d0577e479eda70f54c4b0e3902d8165
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 9.5 MB/s eta 0:00:00
# ...
#   Created wheel for quinine: filename=quinine-0.3.0-py3-none-any.whl size=20796 sha256=6369dc0252205df0eac05ae1f8bd52071595b210e648a1bbaa4dac8223c1d40d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2c3miuks/wheels/4a/c8/cc/851a7103361e64cb16f5045167d8a5063bb57d5813504f8777
# Successfully built quinine
# ...

# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy.git to /tmp/pip-req-build-_rzgnloc
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy.git /tmp/pip-req-build-_rzgnloc
#   Resolved https://github.com/awslabs/fast-differential-privacy.git to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=45b3a4122aae8a675d7847de739b217aa0125757c4703fe08968b38dbffd297d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-49w6lx4j/wheels/09/8c/77/183c75a4d820b35303869508fe5f4b2b39556fe947c4983da8
# Successfully built fastDP
# ...

# %%
# !python differentially_private/baseline_train.py --config=configs/dp/cifar10lppart.yaml --log_dir=logs/dplppart_cifar10_lr_1_nm_0.1_mt_0_sd_1 --project_name=dplppart_cifar10 --group_name=dplppart_cifar10 --run_name dp_lp_cifar10_lr_1_nm_0.1_mt_0_sd_1 --optimizer.args.lr=1 --no_wandb --seed 1
# Out:
# ...
# 100% 170498071/170498071 [00:04<00:00, 41887203.11it/s]
# Extracting /u/scr/ananya//cifar10_dataset/cifar-10-python.tar.gz to /u/scr/ananya//cifar10_dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# Files already downloaded and verified
# Using origin parameters for the ghost differentiation trick......
# Number of trainable components:  2 ; Number of trainable layers:  1
# >>>>>>>>>>>>>>>>> Applying  automatic  per-sample gradient clipping.
# ...
