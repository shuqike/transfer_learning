# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/
# Out:
# /content/drive/Othercomputers/My Mac/transfer_learning

# %%
# %pip install .
# Out:
# Processing /content/drive/Othercomputers/My Mac/transfer_learning
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 8.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/shuqike/quinine.git
# Out:
# ...
#   Cloning https://github.com/shuqike/quinine.git to /tmp/pip-req-build-h2g2_38p
#   Running command git clone --filter=blob:none --quiet https://github.com/shuqike/quinine.git /tmp/pip-req-build-h2g2_38p
#   Resolved https://github.com/shuqike/quinine.git to commit 77b7195f6d0577e479eda70f54c4b0e3902d8165
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.8 MB/s eta 0:00:00
# ...
#   Created wheel for quinine: filename=quinine-0.3.0-py3-none-any.whl size=20796 sha256=9de94dc6c29926f0be84fa0aa3998e72e6dc8c35f7b6eb28446d963d54396042
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w_gux20y/wheels/4a/c8/cc/851a7103361e64cb16f5045167d8a5063bb57d5813504f8777
# Successfully built quinine
# ...

# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy.git to /tmp/pip-req-build-ftn5ln0s
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy.git /tmp/pip-req-build-ftn5ln0s
#   Resolved https://github.com/awslabs/fast-differential-privacy.git to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=502d8b5c45c57d57b70fa4af374f98d02b3d14deec460d91763e07994b0ca143
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v0zre7fe/wheels/09/8c/77/183c75a4d820b35303869508fe5f4b2b39556fe947c4983da8
# Successfully built fastDP
# ...

# %%
# !python differentially_private/baseline_train.py --config=configs/dp/cifar10lpft0.yaml --log_dir=logs/dplpft_cifar10_lr_0.1_nm_0.1_mt_0_sd_0 --project_name=dplpft_cifar10 --group_name=dplpft_cifar10 --run_name dp_lpft_cifar10_lr_0.1_nm_0.1_mt_0_sd_0 --optimizer.args.lr=0.1 --no_wandb --seed 0
# Out:
# ...
# 100% 170498071/170498071 [00:04<00:00, 35259307.46it/s]
# Extracting /u/scr/ananya//cifar10_dataset/cifar-10-python.tar.gz to /u/scr/ananya//cifar10_dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# using pretrained linear head
# debug Parameter containing:
# tensor([[-0.2295, -0.0271, -0.0489,  ...,  0.0154,  0.2836, -0.2161],
#         [ 0.0837, -0.0732,  0.1003,  ..., -0.0006, -0.0736,  0.1956],
#         [-0.1228, -0.0203, -0.0253,  ...,  0.0932,  0.0272, -0.0474],
#         ...,
# ...
