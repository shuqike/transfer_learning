# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/transfer_learning/
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/

# %%
# %pip install .

# %%
# %pip install git+https://github.com/shuqike/quinine.git

# %%
# %pip install opacus

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco3_300ep_dplp7ft3_cifar10_lr_0.025_nm_0.3_mt_0_sd_2 --project_name=dplpftyes_cifar10 --group_name=dplpftyes_cifar10 --run_name moco3_300ep_dp_lp7ft3_cifar10_lr_0.025_nm_0.3_mt_0_sd_2 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 2 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/r-50-300ep.pth.tar'

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco3_300ep_dplp7ft3_cifar10_lr_0.05_nm_0.3_mt_0_sd_2 --project_name=dplpftyes_cifar10 --group_name=dplpftyes_cifar10 --run_name moco3_300ep_dp_lp7ft3_cifar10_lr_0.05_nm_0.3_mt_0_sd_2 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 2 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/r-50-300ep.pth.tar'

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco3_300ep_dplp7ft3_cifar10_lr_0.1_nm_0.3_mt_0_sd_2 --project_name=dplpftyes_cifar10 --group_name=dplpftyes_cifar10 --run_name moco3_300ep_dp_lp7ft3_cifar10_lr_0.1_nm_0.3_mt_0_sd_2 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 2 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/r-50-300ep.pth.tar'
