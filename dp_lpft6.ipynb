# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/transfer_learning/
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/

# %%
# %pip install .

# %%
# %pip install git+https://github.com/shuqike/quinine.git

# %%
# %pip install opacus

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_0 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 0 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_1 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 1 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_2 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 2 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_0 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 0 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_1 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 1 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_2 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 2 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_0 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 0 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_1 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 1 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_2 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 2 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_0 --optimizer.args.lr=0.025 --full_ft_epoch=5 --no_wandb --seed 0 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_1 --optimizer.args.lr=0.025 --full_ft_epoch=5 --no_wandb --seed 1 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name moco3_1000ep_lp5ft5_cifar10_lr_0.025_nm_0_mt_0_sd_2 --optimizer.args.lr=0.025 --full_ft_epoch=5 --no_wandb --seed 2 --model.args.checkpoint_path=cl/r-50-1000ep.pth.tar
