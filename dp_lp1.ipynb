# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/transfer_learning/
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/

# %%
# %pip install .

# %%
# %pip install git+https://github.com/shuqike/quinine.git

# %%
# %pip install opacus

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco2_200ep_dplpfull_cifar10_lr_0.1_nm_0.3_mt_0_sd_0 --project_name=dplpfull_cifar10 --group_name=dplpfull_cifar10 --run_name moco2_200ep_dp_lpfull_cifar10_lr_0.1_nm_0.3_mt_0_sd_0 --optimizer.args.lr=0.1 --no_wandb --seed 0 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/moco_v2_200ep_pretrain.pth.tar'

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco2_200ep_dplpfull_cifar10_lr_0.05_nm_0.3_mt_0_sd_0 --project_name=dplpfull_cifar10 --group_name=dplpfull_cifar10 --run_name moco2_200ep_dp_lpfull_cifar10_lr_0.05_nm_0.3_mt_0_sd_0 --optimizer.args.lr=0.05 --no_wandb --seed 0 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/moco_v2_200ep_pretrain.pth.tar'

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10lpfull.yaml --log_dir=logs/moco2_200ep_dplpfull_cifar10_lr_0.025_nm_0.3_mt_0_sd_0 --project_name=dplpfull_cifar10 --group_name=dplpfull_cifar10 --run_name moco2_200ep_dp_lpfull_cifar10_lr_0.025_nm_0.3_mt_0_sd_0 --optimizer.args.lr=0.025 --no_wandb --seed 0 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/moco_v2_200ep_pretrain.pth.tar'
