# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/
# Out:
# /content/drive/Othercomputers/My Mac/transfer_learning

# %%
# %pip install .
# Out:
# Processing /content/drive/Othercomputers/My Mac/transfer_learning
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.7 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/shuqike/quinine.git
# Out:
# ...
#   Cloning https://github.com/shuqike/quinine.git to /tmp/pip-req-build-if6hbd4v
#   Running command git clone --filter=blob:none --quiet https://github.com/shuqike/quinine.git /tmp/pip-req-build-if6hbd4v
#   Resolved https://github.com/shuqike/quinine.git to commit 77b7195f6d0577e479eda70f54c4b0e3902d8165
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.6 MB/s eta 0:00:00
# ...
#   Created wheel for quinine: filename=quinine-0.3.0-py3-none-any.whl size=20796 sha256=a03755fbb35a45e9146c2b84ee01ec772122d00c7f7c7bf32ddf355f0116daeb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z7vmki4k/wheels/4a/c8/cc/851a7103361e64cb16f5045167d8a5063bb57d5813504f8777
# Successfully built quinine
# ...

# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy.git to /tmp/pip-req-build-ux2dwqi4
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy.git /tmp/pip-req-build-ux2dwqi4
#   Resolved https://github.com/awslabs/fast-differential-privacy.git to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=b57fc1307900304f61860d8e85e3649c53c8e4d076dd1bfe326b6dcb869be5cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eh8sf3zv/wheels/09/8c/77/183c75a4d820b35303869508fe5f4b2b39556fe947c4983da8
# Successfully built fastDP
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lpfull_cifar10_lr_0.05_nm_0_mt_0_sd_1 --project_name=lpfull_cifar10 --group_name=lpfull_cifar10 --run_name lpfull_cifar10_lr_0.05_nm_0_mt_0_sd_1 --optimizer.args.lr=0.05 --no_wandb --seed 1
# Out:
# ...
# 100% 170498071/170498071 [00:05<00:00, 29563648.54it/s]
# Extracting /u/scr/ananya//cifar10_dataset/cifar-10-python.tar.gz to /u/scr/ananya//cifar10_dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lpfull_cifar10_lr_0.05_nm_0_mt_0_sd_2 --project_name=lpfull_cifar10 --group_name=lpfull_cifar10 --run_name lpfull_cifar10_lr_0.05_nm_0_mt_0_sd_2 --optimizer.args.lr=0.05 --no_wandb --seed 2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lpfull_cifar10_lr_0.1_nm_0_mt_0_sd_0 --project_name=lpfull_cifar10 --group_name=lpfull_cifar10 --run_name lpfull_cifar10_lr_0.1_nm_0_mt_0_sd_0 --optimizer.args.lr=0.1 --no_wandb --seed 0
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lpfull_cifar10_lr_0.1_nm_0_mt_0_sd_2 --project_name=lpfull_cifar10 --group_name=lpfull_cifar10 --run_name lpfull_cifar10_lr_0.1_nm_0_mt_0_sd_2 --optimizer.args.lr=0.1 --no_wandb --seed 2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %% [markdown]
# lp7ft3

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_0 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 0
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_1 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 1
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.1_nm_0_mt_0_sd_2 --optimizer.args.lr=0.1 --full_ft_epoch=7 --no_wandb --seed 2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_0 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 0
# Out:
# WARNING:root:Removed old run directory.
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_1 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 1
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.05_nm_0_mt_0_sd_2 --optimizer.args.lr=0.05 --full_ft_epoch=7 --no_wandb --seed 2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_0 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_0 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 0
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_1 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_1 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 1
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !python unlabeled_extrapolation/baseline_train.py --config=configs/nondp/cifar10lpfull.yaml --log_dir=logs/lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_2 --project_name=lpftyes_cifar10 --group_name=lpftyes_cifar10 --run_name lp7ft3_cifar10_lr_0.025_nm_0_mt_0_sd_2 --optimizer.args.lr=0.025 --full_ft_epoch=7 --no_wandb --seed 2
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...
