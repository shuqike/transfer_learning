# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/

# %%
# %pip install .

# %%
# %pip install git+https://github.com/shuqike/quinine.git

# %%
# %pip install opacus

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git

# %%
# !python3 differentially_private/baseline_train.py --config=configs/dp/cifar10.yaml --log_dir=logs/moco3_300ep_dpft_cifar10_lr_0.05_nm_0.3_mt_0_sd_0 --project_name=dpft_cifar10 --group_name=dpft_cifar10 --run_name moco3_300ep_dp_ft_cifar10_lr_0.05_nm_0.3_mt_0_sd_0 --optimizer.args.lr=0.05 --no_wandb --seed 0 --privacy_engine.args.noise_multiplier=0.3 --model.args.checkpoint_path='cl/r-50-300ep.pth.tar'
