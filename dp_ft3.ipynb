# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/My Mac/transfer_learning/
# Out:
# /content/drive/Othercomputers/My Mac/transfer_learning

# %%
# %pip install .
# Out:
# Processing /content/drive/Othercomputers/My Mac/transfer_learning
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 50.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 6.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/shuqike/quinine.git
# Out:
# ...
#   Cloning https://github.com/shuqike/quinine.git to /tmp/pip-req-build-x0h0v9k2
#   Running command git clone --filter=blob:none --quiet https://github.com/shuqike/quinine.git /tmp/pip-req-build-x0h0v9k2
#   Resolved https://github.com/shuqike/quinine.git to commit 77b7195f6d0577e479eda70f54c4b0e3902d8165
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.8 MB/s eta 0:00:00
# ...
#   Created wheel for quinine: filename=quinine-0.3.0-py3-none-any.whl size=20796 sha256=60d587e6c1ade176c81ad0691aa10c998c9835a037cfd3ac0239b8a4c1db2c3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-evq_3rbg/wheels/4a/c8/cc/851a7103361e64cb16f5045167d8a5063bb57d5813504f8777
# Successfully built quinine
# ...

# %%
# %pip install opacus
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# %pip install git+https://github.com/awslabs/fast-differential-privacy.git
# Out:
# ...
#   Cloning https://github.com/awslabs/fast-differential-privacy.git to /tmp/pip-req-build-vipcvgxc
#   Running command git clone --filter=blob:none --quiet https://github.com/awslabs/fast-differential-privacy.git /tmp/pip-req-build-vipcvgxc
#   Resolved https://github.com/awslabs/fast-differential-privacy.git to commit 053a82df69e48698053570e90bc24cd8bba26daf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastDP: filename=fastDP-1.1.0-py3-none-any.whl size=101667 sha256=93b9f31282525d88f687a1cfa8f699b345182d9410bb9bc69142fa586cf29a9c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-igdmx71m/wheels/09/8c/77/183c75a4d820b35303869508fe5f4b2b39556fe947c4983da8
# Successfully built fastDP
# ...

# %%
# !python differentially_private/baseline_train.py --config=configs/dp/cifar10.yaml --log_dir=logs/dpft_cifar10_lr_0.5_nm_0.1_mt_0_sd_1 --project_name=dpft_cifar10 --group_name=dpft_cifar10 --run_name dp_ft_cifar10_lr_0.5_nm_0.1_mt_0_sd_1 --optimizer.args.lr=0.5 --no_wandb --seed 0
# Out:
# ...
# 100% 170498071/170498071 [00:02<00:00, 69929226.09it/s]
# Extracting /u/scr/ananya//cifar10_dataset/cifar-10-python.tar.gz to /u/scr/ananya//cifar10_dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified
# Files already downloaded and verified
# debug Parameter containing:
# tensor([[ 6.6970e-03, -6.0678e-03,  1.8278e-02,  ...,  1.2842e-02,
#          -2.0258e-02,  9.5236e-05],
#         [-2.0734e-02, -1.2677e-02, -1.2411e-02,  ...,  1.0510e-02,
#           3.4056e-04,  1.4999e-03],
# ...
